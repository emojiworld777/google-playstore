# %% [markdown]
# # Importing the Library

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
import calendar

# %% [markdown]
# # Loading the dataset as dataframe

# %%
df= pd.read_csv('S:\eda and sql\Google-Playstore.csv')

# %%
rows=df.shape[0]
coloumns=df.shape[1]

# %% [markdown]
# # Printing the number of rows and the column in the dataset

# %%
print('there are {} rows and {} columns in the dataset'.format(rows,coloumns))
print(df.shape)
# Out:
# there are 2312944 rows and 24 columns in the dataset
# (2312944, 24)

# %%
df.head(5)
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# 2              50.0                58  True    0.0  ...
# 3              10.0                19  True    0.0  ...
# 4             100.0               478  True    0.0  ...
#
#                   Developer Website              Developer Email  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com
# 1   https://webserveis.netlify.app/         webserveis@gmail.com
# 2                               NaN          vnacrewit@gmail.com
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com
# 4       http://www.horodyski.com.pl    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 20:19:35
# 1            False          False  2021-06-15 20:19:35
# 2            False          False  2021-06-15 20:19:35
# 3            False          False  2021-06-15 20:19:35
# 4            False          False  2021-06-15 20:19:35
#
# [5 rows x 24 columns]

# %%
df.columns= [c.replace(' ','_')for c in df.columns]

# %% [markdown]
# # Finding the null values in the dataset

# %%
df.isnull().sum()
# Out:
# App_Name                  2
# App_Id                    0
# Category                  0
# Rating                22883
# Rating_Count          22883
# Installs                107
# Minimum_Installs        107
# Maximum_Installs          0
# Free                      0
# Price                     0
# Currency                135
# Size                    196
# Minimum_Android        6530
# Developer_Id             33
# Developer_Website    760835
# Developer_Email          31
# Released              71053
# Last_Updated              0
# Content_Rating            0
# Privacy_Policy       420953
# Ad_Supported              0
# In_App_Purchases          0
# Editors_Choice            0
# Scraped_Time              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App_Name           object
#  1   App_Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating_Count       float64
#  5   Installs           object
#  6   Minimum_Installs   float64
#  7   Maximum_Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum_Android    object
#  13  Developer_Id       object
#  14  Developer_Website  object
#  15  Developer_Email    object
#  16  Released           object
#  17  Last_Updated       object
#  18  Content_Rating     object
#  19  Privacy_Policy     object
#  20  Ad_Supported       bool
#  21  In_App_Purchases   bool
#  22  Editors_Choice     bool
#  23  Scraped_Time       object
# dtypes: bool(4), float64(4), int64(1), object(15)
# memory usage: 361.8+ MB

# %%
df.describe()
# Out:
#              Rating  Rating_Count  Minimum_Installs  Maximum_Installs  \
# count  2.290061e+06  2.290061e+06      2.312837e+06      2.312944e+06
# mean   2.203152e+00  2.864839e+03      1.834452e+05      3.202017e+05
# std    2.106223e+00  2.121626e+05      1.513144e+07      2.355495e+07
# min    0.000000e+00  0.000000e+00      0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00      5.000000e+01      8.400000e+01
# 50%    2.900000e+00  6.000000e+00      5.000000e+02      6.950000e+02
# 75%    4.300000e+00  4.200000e+01      5.000000e+03      7.354000e+03
# max    5.000000e+00  1.385576e+08      1.000000e+10      1.205763e+10
#
#               Price
# count  2.312944e+06
# mean   1.034992e-01
# std    2.633127e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    4.000000e+02

# %%
df.tail(20)
# Out:
#                                              App_Name  \
# 2312924                How to Make Money From Website
# 2312925  GOKarli Carrera Rennbahn und Dart Onlineshop
# 2312926                         Asset Data Collection
# 2312927                         Gear Ratio Calculator
# 2312928                      Nutrishop Boise Meridian
# 2312929            Murottal Muh Tha al Junayd Offline
# 2312930                                           PAX
# 2312931                                   Driving Day
# 2312932                       Hopeless 2: Cave Escape
# 2312933                Caustic Editor for VolcaSample
# 2312934               Vietnamese - English Translator
# 2312935                              Floral Wallpaper
# 2312936                             Engineers Careers
# 2312937              STMIK Mercusuar - Aditya Rachman
# 2312938                   Lero TOEFL Recorder + Timer
# 2312939                                      大俠客—熱血歸來
# 2312940                                    ORU Online
# 2312941                                Data Structure
# 2312942                                   Devi Suktam
# 2312943                  Biliyor Musun - Sonsuz Yarış
#
#                                           App_Id           Category  Rating  \
# 2312924                     com.rojas.htmkmfrmst  Books & Reference     0.0
# 2312925                          de.gokarli.shop           Shopping     0.0
# 2312926             com.linq.assetdatacollection           Business     0.0
# 2312927              jp.abt.lopnur.gearratiocalc             Sports     0.0
# 2312928                 com.tapmango.nutrishopbm   Health & Fitness     0.0
# 2312929          com.andromo.dev471643.app436193      Entertainment     4.4
# 2312930               com.apreciasoft.mobile.pax     Travel & Local     3.3
# 2312931                       com.day.drivingday      Entertainment     2.8
# 2312932                      com.upopa.hopeless2             Action     4.3
# 2312933         com.singlecellsoftware.kvsampler      Music & Audio     4.0
# 2312934  com.eliminatesapps.vietnamesetranslator          Education     0.0
# 2312935               com.arfdev.floralwallpaper    Personalization     0.0
# 2312936                  com.eventapps.eventapps           Business     0.0
# 2312937             com.aplikasi.datapribadiadit          Education     0.0
# 2312938                           com.toefltimer          Education     3.4
# 2312939                            com.rxsj.ssjj       Role Playing     4.3
# 2312940                 com.threedream.oruonline          Education     0.0
# 2312941     datastructure.appoworld.datastucture          Education     0.0
# 2312942                        ishan.devi.suktam      Music & Audio     3.5
# 2312943                com.yyazilim.biliyormusun             Trivia     5.0
#
#          Rating_Count    Installs  Minimum_Installs  Maximum_Installs   Free  \
# 2312924           0.0          1+               1.0                 2   True
# 2312925           0.0      1,000+            1000.0              2418   True
# 2312926           0.0        500+             500.0               687   True
# 2312927           0.0        100+             100.0               201  False
# 2312928           0.0        100+             100.0               195   True
# 2312929          23.0      1,000+            1000.0              1783   True
# 2312930           7.0        100+             100.0               388   True
# 2312931        1002.0    500,000+          500000.0            590469   True
# 2312932      103466.0  5,000,000+         5000000.0           7274660   True
# 2312933         344.0    500,000+          500000.0            814548   True
# 2312934           0.0          5+               5.0                 6   True
# 2312935           0.0      1,000+            1000.0              1302   True
# 2312936           0.0        100+             100.0               353   True
# 2312937           0.0          5+               5.0                 7   True
# 2312938          17.0      1,000+            1000.0              1980   True
# 2312939       16775.0    100,000+          100000.0            337109   True
# 2312940           0.0        100+             100.0               430   True
# 2312941           0.0        100+             100.0               202   True
# 2312942           8.0      1,000+            1000.0              2635   True
# 2312943          12.0        100+             100.0               354   True
#
#          Price  ...                  Developer_Website  \
# 2312924   0.00  ...                                NaN
# 2312925   0.00  ...            https://www.gokarli.de/
# 2312926   0.00  ...                    http://linq.io/
# 2312927   2.49  ...                  http://www.abt.jp
# 2312928   0.00  ...            http://www.tapmango.com
# 2312929   0.00  ...                                NaN
# 2312930   0.00  ...             http://www.asremis.com
# 2312931   0.00  ...                                NaN
# 2312932   0.00  ...               http://www.upopa.com
# 2312933   0.00  ...  http://www.singlecellsoftware.com
# 2312934   0.00  ...  https://af24d8239.app-ads-txt.com
# 2312935   0.00  ...                                NaN
# 2312936   0.00  ...                                NaN
# 2312937   0.00  ...                                NaN
# 2312938   0.00  ...     https://lerodoe.wordpress.com/
# 2312939   0.00  ...          http://www.4399sy.com.hk/
# 2312940   0.00  ...                http://www.oru.edu/
# 2312941   0.00  ...                                NaN
# 2312942   0.00  ...  https://a70f78905.app-ads-txt.com
# 2312943   0.00  ...                                NaN
#
#                       Developer_Email      Released  Last_Updated  \
# 2312924            Wrojas29@gmail.com  Nov 22, 2019  Nov 22, 2019
# 2312925               info@GOKarli.de  Feb 10, 2020  May 28, 2021
# 2312926              linq@entronix.io  Dec 13, 2018  Mar 24, 2021
# 2312927              abtdev@gmail.com  Jun 19, 2012  Nov 09, 2012
# 2312928          support@tapmango.com  Mar 27, 2018  Mar 27, 2018
# 2312929       missbundanino@gmail.com   Oct 2, 2015  Apr 15, 2018
# 2312930        ventas@apreciasoft.com   Sep 2, 2019  Nov 26, 2020
# 2312931         maan1patel0@gmail.com  Jun 10, 2020  Jun 10, 2020
# 2312932             support@upopa.com  Oct 29, 2015  Mar 06, 2017
# 2312933          causticapp@gmail.com  Dec 11, 2014  Dec 11, 2014
# 2312934      eliminatesapps@gmail.com  Jun 15, 2020  Aug 31, 2020
# 2312935            arfdev56@gmail.com  Jul 19, 2018  Nov 13, 2019
# 2312936    rami.osama.selim@gmail.com   Mar 5, 2020  Feb 29, 2020
# 2312937      rachmanaditya5@gmail.com  Jan 15, 2020  Jan 15, 2020
# 2312938            lero.doe@gmail.com  May 22, 2018  Dec 14, 2018
# 2312939           ssjjcomhk@gmail.com           NaN  Jun 01, 2021
# 2312940     3DreamDeveloper@gmail.com  Jan 17, 2018  Feb 02, 2018
# 2312941  appoworld.official@gmail.com  Aug 19, 2018  Aug 19, 2018
# 2312942           ruchisono@gmail.com   Aug 1, 2016  May 05, 2021
# 2312943     yyazilimdevelop@gmail.com   Aug 9, 2019  Aug 19, 2019
#
#         Content_Rating                                     Privacy_Policy  \
# 2312924       Everyone                                                NaN
# 2312925       Everyone                 https://www.gokarli.de/Datenschutz
# 2312926       Everyone      https://entronix.io/index.php/privacy-policy/
# 2312927       Everyone                                                NaN
# 2312928       Everyone                                                NaN
# 2312929       Everyone  https://docs.google.com/document/d/1AtSjUzTam2...
# 2312930       Everyone           https://as-nube.com/privacyPolitics.html
# 2312931       Everyone  https://docs.google.com/document/d/1I310VsRWy8...
# 2312932           Teen  http://www.upopa.com/games/hopeless2/privacypo...
# 2312933       Everyone      http://www.singlecellsoftware.com/PRIVACY.txt
# 2312934       Everyone           https://sites.google.com/view/redli/home
# 2312935       Everyone  https://docs.google.com/document/d/14UGI886tB6...
# 2312936       Everyone                                                NaN
# 2312937       Everyone                                                NaN
# 2312938       Everyone  https://lerodoe.wordpress.com/app-privacy-poli...
# 2312939           Teen             http://a.4399sy.com.hk/user/aggreement
# 2312940       Everyone    http://www.oru.edu/about-oru/privacy-policy.php
# 2312941       Everyone  https://appoworld.000webhostapp.com/datastruct...
# 2312942       Everyone  https://docs.google.com/document/d/1x-9reZuLRX...
# 2312943       Everyone  https://biliyor-musun-sons.flycricket.io/priva...
#
#         Ad_Supported In_App_Purchases Editors_Choice         Scraped_Time
# 2312924         True            False          False  2021-06-16 12:59:18
# 2312925        False            False          False  2021-06-16 12:59:18
# 2312926        False            False          False  2021-06-16 12:59:18
# 2312927        False            False          False  2021-06-16 12:59:18
# 2312928        False            False          False  2021-06-16 12:59:18
# 2312929         True            False          False  2021-06-16 12:59:18
# 2312930        False            False          False  2021-06-16 12:59:18
# 2312931         True            False          False  2021-06-16 12:59:18
# 2312932         True             True          False  2021-06-16 12:59:18
# 2312933        False            False          False  2021-06-16 12:59:18
# 2312934         True            False          False  2021-06-16 12:59:18
# 2312935         True            False          False  2021-06-16 12:59:18
# 2312936        False            False          False  2021-06-16 12:59:18
# 2312937        False            False          False  2021-06-16 12:59:18
# 2312938         True            False          False  2021-06-16 12:59:18
# 2312939        False            False          False  2021-06-16 12:59:18
# 2312940        False            False          False  2021-06-16 12:59:19
# 2312941        False            False          False  2021-06-16 12:59:19
# 2312942         True            False          False  2021-06-16 12:59:19
# 2312943         True            False          False  2021-06-16 12:59:19
#
# [20 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['App_Name', 'App_Id', 'Category', 'Rating', 'Rating_Count', 'Installs',
#        'Minimum_Installs', 'Maximum_Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum_Android', 'Developer_Id', 'Developer_Website',
#        'Developer_Email', 'Released', 'Last_Updated', 'Content_Rating',
#        'Privacy_Policy', 'Ad_Supported', 'In_App_Purchases', 'Editors_Choice',
#        'Scraped_Time'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)
df.sample(5)
# Out:
#                                                   App_Name  \
# 154446                         Bekzod Haqqiyev qo'shiqlari
# 738534                                           City Silo
# 2081079                                     File Manager Z
# 176662                                     E Professor ICT
# 1236845  payfresh-online fruits and vegetables delivery...
#
#                               App_Id       Category  Rating  Rating_Count  \
# 154446   com.uzmedia.bekzod_haqqiyev  Music & Audio     4.5         164.0
# 738534        com.togoorder.citysilo   Food & Drink     0.0           0.0
# 2081079      com.simulas.filemanager          Tools     0.0           0.0
# 176662      com.kweera.eprofessorict      Education     5.0          16.0
# 1236845           com.again.payfresh       Shopping     4.2          34.0
#
#         Installs  Minimum_Installs  Maximum_Installs  Free  Price Currency  \
# 154446   50,000+           50000.0             73010  True    0.0      USD
# 738534       10+              10.0                49  True    0.0      USD
# 2081079      10+              10.0                33  True    0.0      USD
# 176662      100+             100.0               130  True    0.0      USD
# 1236845   1,000+            1000.0              2500  True    0.0      USD
#
#          Size Minimum_Android           Developer_Id  \
# 154446    58M      4.1 and up               Navosoft
# 738534    51M      5.0 and up  ToGoTechnologies, LLC
# 2081079  5.0M      5.0 and up                Simulas
# 176662    25M    4.0.3 and up                K Weera
# 1236845  3.3M      4.1 and up            payfresh.in
#
#                           Developer_Website            Developer_Email  \
# 154446                                  NaN         uzbmuz19@gmail.com
# 738534           http://www.thecitysilo.com  info@togotechnologies.com
# 2081079              https://www.simulas.in         support@simulas.in
# 176662   https://eprofessor-kweera.web.app/          kuwesri@gmail.com
# 1236845                https://payfresh.in/           info@payfresh.in
#
#              Released  Last_Updated Content_Rating  \
# 154446   Jun 25, 2019  Jun 28, 2019       Everyone
# 738534    Apr 2, 2020  Apr 02, 2020       Everyone
# 2081079  Nov 16, 2019  Nov 16, 2019       Everyone
# 176662   Apr 24, 2020  Apr 17, 2021       Everyone
# 1236845  Oct 19, 2020  Oct 22, 2020       Everyone
#
#                                             Privacy_Policy  Ad_Supported  \
# 154446           https://telegra.ph/Privacy-Policy-06-21-9          True
# 738534   https://togoorder.com/web/Home/TermsOfService?...         False
# 2081079                                                NaN          True
# 176662        https://www.kweera.com/privacypolicyteaching         False
# 1236845                                                NaN         False
#
#          In_App_Purchases  Editors_Choice         Scraped_Time
# 154446              False           False  2021-06-15 22:51:48
# 738534              False           False  2021-06-16 08:14:29
# 2081079             False           False  2021-06-16 09:36:57
# 176662              False           False  2021-06-15 23:17:17
# 1236845             False           False  2021-06-15 21:14:25

# %% [markdown]
# Looking for unique values in category column

# %%
pd.unique(df['Category'])
# Out:
# array(['Adventure', 'Tools', 'Productivity', 'Communication', 'Social',
#        'Libraries & Demo', 'Lifestyle', 'Personalization', 'Racing',
#        'Maps & Navigation', 'Travel & Local', 'Food & Drink',
#        'Books & Reference', 'Medical', 'Puzzle', 'Entertainment',
#        'Arcade', 'Auto & Vehicles', 'Photography', 'Health & Fitness',
#        'Education', 'Shopping', 'Board', 'Music & Audio', 'Sports',
#        'Beauty', 'Business', 'Educational', 'Finance', 'News & Magazines',
#        'Casual', 'Art & Design', 'House & Home', 'Card', 'Events',
#        'Trivia', 'Weather', 'Strategy', 'Word', 'Video Players & Editors',
#        'Action', 'Simulation', 'Music', 'Dating', 'Role Playing',
#        'Casino', 'Comics', 'Parenting'], dtype=object)

# %% [markdown]
# Defining the function to veiw the insights of the dataset

# %%
def printinfo():
    temp = pd.DataFrame(index=df.columns)
    temp['dataType'] = df.dtypes
    temp['nullCount']=df.isnull().sum()
    temp['uniqueCount']=df.nunique()
    return temp

# %%
df.head(1)
# Out:
#   App_Name               App_Id   Category  Rating  Rating_Count Installs  \
# 0  Gakondo  com.ishakwe.gakondo  Adventure     0.0           0.0      10+
#
#    Minimum_Installs  Maximum_Installs  Free  Price Currency Size  \
# 0              10.0                15  True    0.0      USD  10M
#
#   Minimum_Android                       Developer_Id  \
# 0      7.1 and up  Jean Confident Irénée NIYIZIBYOSE
#
#              Developer_Website         Developer_Email      Released  \
# 0  https://beniyizibyose.tk/#/  jean21101999@gmail.com  Feb 26, 2020
#
#    Last_Updated Content_Rating                      Privacy_Policy  \
# 0  Feb 26, 2020       Everyone  https://beniyizibyose.tk/projects/
#
#    Ad_Supported  In_App_Purchases  Editors_Choice         Scraped_Time
# 0         False             False           False  2021-06-15 20:19:35

# %%
printinfo()
# Out:
#                   dataType  nullCount  uniqueCount
# App_Name            object          2      2177944
# App_Id              object          0      2312944
# Category            object          0           48
# Rating             float64      22883           42
# Rating_Count       float64      22883        38482
# Installs            object        107           22
# Minimum_Installs   float64        107           22
# Maximum_Installs     int64          0       251563
# Free                  bool          0            2
# Price              float64          0         1063
# Currency            object        135           15
# Size                object        196         1657
# Minimum_Android     object       6530          154
# Developer_Id        object         33       758371
# Developer_Website   object     760835       810440
# Developer_Email     object         31       950456
# Released            object      71053         4158
# Last_Updated        object          0         3918
# Content_Rating      object          0            6
# Privacy_Policy      object     420953       977743
# Ad_Supported          bool          0            2
# In_App_Purchases      bool          0            2
# Editors_Choice        bool          0            2
# Scraped_Time        object          0        67374

# %%
df.isnull().sum()
# Out:
# App_Name                  2
# App_Id                    0
# Category                  0
# Rating                22883
# Rating_Count          22883
# Installs                107
# Minimum_Installs        107
# Maximum_Installs          0
# Free                      0
# Price                     0
# Currency                135
# Size                    196
# Minimum_Android        6530
# Developer_Id             33
# Developer_Website    760835
# Developer_Email          31
# Released              71053
# Last_Updated              0
# Content_Rating            0
# Privacy_Policy       420953
# Ad_Supported              0
# In_App_Purchases          0
# Editors_Choice            0
# Scraped_Time              0
# dtype: int64

# %% [markdown]
# # Finding the rows and columns in Rating having the Null values

# %%
df[df['Rating'].isnull()]
# Out:
#                                   App_Name  \
# 115                               VM-Delay
# 210                               Promotor
# 284                             xrsta xatr
# 501                              GridChats
# 662                  Restaurant POS(Admin)
# ...                                    ...
# 2312553               Merlins Idle Apelsin
# 2312712                   Joule Mobile App
# 2312751                  Iris Profissional
# 2312764                   Wool Sort Puzzle
# 2312842  Living Goods (Innovation Network)
#
#                                                     App_Id          Category  \
# 115                                       com.irv.vm_delay             Tools
# 210                              com.touchesbegan.promotor      Productivity
# 284                                         com.xrsta.xatr     Entertainment
# 501                              com.thegridnet.conference     Communication
# 662                                org.wisdomfish.posadmin             Tools
# ...                                                    ...               ...
# 2312553                      com.elitegamesltd.merlinsidle        Simulation
# 2312712                      com.companyname.Joule.Xamarin      Productivity
# 2312751                       com.sys4web.irisprofissional  Health & Fitness
# 2312764                       com.cla.wool.ballsort.puzzle            Puzzle
# 2312842  org.medicmobile.webapp.mobile.livinggoods_inno...           Medical
#
#          Rating  Rating_Count Installs  Minimum_Installs  Maximum_Installs  \
# 115         NaN           NaN      50+              50.0                71
# 210         NaN           NaN     100+             100.0               135
# 284         NaN           NaN      10+              10.0                14
# 501         NaN           NaN      50+              50.0                92
# 662         NaN           NaN      10+              10.0                18
# ...         ...           ...      ...               ...               ...
# 2312553     NaN           NaN      10+              10.0                44
# 2312712     NaN           NaN     100+             100.0               215
# 2312751     NaN           NaN      50+              50.0                62
# 2312764     NaN           NaN  10,000+           10000.0             10681
# 2312842     NaN           NaN      50+              50.0                80
#
#          Free  Price Currency                Size     Minimum_Android  \
# 115      True    0.0      USD  Varies with device  Varies with device
# 210      True    0.0      USD  Varies with device  Varies with device
# 284      True    0.0      USD  Varies with device  Varies with device
# 501      True    0.0      USD  Varies with device  Varies with device
# 662      True    0.0      USD  Varies with device  Varies with device
# ...       ...    ...      ...                 ...                 ...
# 2312553  True    0.0      USD  Varies with device  Varies with device
# 2312712  True    0.0      USD  Varies with device  Varies with device
# 2312751  True    0.0      USD  Varies with device  Varies with device
# 2312764  True    0.0      USD                 NaN  Varies with device
# 2312842  True    0.0      USD  Varies with device  Varies with device
#
#              Developer_Id            Developer_Website  \
# 115                IVR.RD                          NaN
# 210          TouchesBegan  http://www.touchesbegan.com
# 284          fremme_gamez                          NaN
# 501       TheGridNet Ltd.         http://gridchats.com
# 662           WisFish.com       http://www.wisfish.com
# ...                   ...                          ...
# 2312553             Badim                          NaN
# 2312712  Guillermo Martos                          NaN
# 2312751           SYS4WEB       http://www.sys4web.com
# 2312764     SUPER CLASSIC                          NaN
# 2312842            Medic.       http://medicmobile.org
#
#                  Developer_Email Released  Last_Updated Content_Rating  \
# 115               iv_dx@mail.com      NaN  Oct 23, 2018       Everyone
# 210        info@touchesbegan.com      NaN  Aug 14, 2017       Everyone
# 284          fremmepen@gmail.com      NaN  Feb 08, 2020     Mature 17+
# 501        support@gridchats.com      NaN  Sep 20, 2018       Everyone
# 662          service@wisfish.com      NaN  Jul 25, 2016       Everyone
# ...                          ...      ...           ...            ...
# 2312553    efgames.net@gmail.com      NaN  Nov 17, 2019       Everyone
# 2312712       guillermo@joule.ie      NaN  Jan 27, 2020       Everyone
# 2312751       mobile@sys4web.com      NaN  Jul 24, 2019       Everyone
# 2312764   superclagame@gmail.com      NaN  Mar 17, 2021       Everyone
# 2312842  android@medicmobile.org      NaN  Oct 08, 2020       Everyone
#
#                                             Privacy_Policy  Ad_Supported  \
# 115                                                    NaN         False
# 210                                                    NaN         False
# 284                                                    NaN         False
# 501                   https://socialecosystem.com/en/terms         False
# 662       http://www.wisdomfish.org/welcome/privacy-policy         False
# ...                                                    ...           ...
# 2312553              http://theelitegames.net/privacy.html         False
# 2312712               https://www.joule.ie/privacy-policy/         False
# 2312751  http://benevolentiav2.azurewebsites.net/static...         False
# 2312764  https://www.dropbox.com/s/4q5wbqlyu4vpery/poli...          True
# 2312842                                                NaN         False
#
#          In_App_Purchases  Editors_Choice         Scraped_Time
# 115                 False           False  2021-06-15 20:19:42
# 210                 False           False  2021-06-15 20:19:48
# 284                 False           False  2021-06-15 20:19:52
# 501                 False           False  2021-06-15 20:20:05
# 662                 False           False  2021-06-15 20:20:14
# ...                   ...             ...                  ...
# 2312553             False           False  2021-06-16 12:58:58
# 2312712             False           False  2021-06-16 12:59:06
# 2312751             False           False  2021-06-16 12:59:08
# 2312764             False           False  2021-06-16 12:59:09
# 2312842             False           False  2021-06-16 12:59:13
#
# [22883 rows x 24 columns]

# %%
df.loc[34453:54345,:]
# Out:
#                            App_Name                                App_Id  \
# 34453  IMMIGRANTS: FRIENDS OR FOES?                   com.mbspringer.imig
# 34454                 Together UCOB                  br.org.ucob.together
# 34455                     EnergyVUE  com.rainforestautomation.energyvuern
# 34456    Fondos de Paisajes Bonitos       com.andromo.dev604137.app583342
# 34457                   Regalprüfer            com.secumundi.regalpruefer
# ...                             ...                                   ...
# 54341                   Bug Climber                     com.aa.bugclimber
# 54342                   世界各国の首都 問題集                jp.co.solcreo.quiz0012
# 54343     Japanese Hmong Dictionary                nerdcats.japanesehmong
# 54344                Smart Retailer            in.socialtitli.retailerapp
# 54345                   Staff Ready    net.staffconnect.mobile.staffready
#
#                 Category  Rating  Rating_Count Installs  Minimum_Installs  \
# 34453   News & Magazines     0.0           0.0      10+              10.0
# 34454             Dating     4.3          35.0   1,000+            1000.0
# 34455       House & Home     2.3          23.0   1,000+            1000.0
# 34456    Personalization     4.9          60.0  10,000+           10000.0
# 34457   Libraries & Demo     0.0           0.0     500+             500.0
# ...                  ...     ...           ...      ...               ...
# 54341             Casual     0.0           0.0   1,000+            1000.0
# 54342          Education     0.0           0.0     500+             500.0
# 54343  Books & Reference     0.0           0.0       1+               1.0
# 54344           Business     4.0           9.0   1,000+            1000.0
# 54345           Business     0.0           0.0      10+              10.0
#
#        Maximum_Installs  Free  Price Currency  Size Minimum_Android  \
# 34453                16  True    0.0      USD  4.7M      4.1 and up
# 34454              3992  True    0.0      USD   14M      4.4 and up
# 34455              1378  True    0.0      USD   53M      5.0 and up
# 34456             13342  True    0.0      USD   49M    2.3.3 and up
# 34457               553  True    0.0      USD   14M      5.0 and up
# ...                 ...   ...    ...      ...   ...             ...
# 54341              3832  True    0.0      USD   80M      4.4 and up
# 54342               605  True    0.0      USD  3.2M      4.0 and up
# 54343                 1  True    0.0      USD  7.3M      4.2 and up
# 54344              1857  True    0.0      USD  8.6M      6.0 and up
# 54345                23  True    0.0      USD  9.9M      5.1 and up
#
#                                 Developer_Id  \
# 34453                    mark burns springer
# 34454  União Centro Oeste Brasileira da IASD
# 34455                  Rainforest Automation
# 34456                           JekApps Inc.
# 34457                         Secumundi GmbH
# ...                                      ...
# 54341                           App Advisory
# 54342                           SOLCREO Inc.
# 54343                               NerdCats
# 54344          Socialtitli Marketing Pvt Ltd
# 54345                          Nobox Limited
#
#                           Developer_Website  \
# 34453     https://www.facebook.com/apks4fun
# 34454          http://together.ucob.org.br/
# 34455  https://www.rainforestautomation.com
# 34456                                   NaN
# 34457              http://www.secumundi.com
# ...                                     ...
# 54341              https://app-advisory.com
# 54342             http://app.solcreo.co.jp/
# 54343                                   NaN
# 54344                                   NaN
# 54345                                   NaN
#
#                                    Developer_Email      Released  \
# 34453                      mbspringer133@gmail.com  May 23, 2017
# 34454                         together@ucob.org.br   Sep 2, 2019
# 34455  rainforest.support@rainforestautomation.com  Sep 27, 2018
# 34456               jessicamedinaminchan@gmail.com  Feb 25, 2017
# 34457                           info@secumundi.com  Mar 28, 2018
# ...                                            ...           ...
# 54341                     anthony@app-advisory.com   Jun 2, 2021
# 54342                          appli@solcreo.co.jp  Feb 28, 2014
# 54343                     muzahid.ashraf@gmail.com  Jan 29, 2021
# 54344                        socialtitli@gmail.com  Jan 20, 2021
# 54345                     support@staffconnect.net  Apr 12, 2021
#
#        Last_Updated Content_Rating  \
# 34453  May 24, 2017       Everyone
# 34454  Nov 17, 2019       Everyone
# 34455  Jan 24, 2021       Everyone
# 34456  Feb 25, 2017       Everyone
# 34457  Jul 07, 2019       Everyone
# ...             ...            ...
# 54341  Jun 02, 2021       Everyone
# 54342  Jun 15, 2018       Everyone
# 54343  Mar 04, 2021       Everyone
# 54344  Mar 19, 2021           Teen
# 54345  Apr 12, 2021       Everyone
#
#                                           Privacy_Policy  Ad_Supported  \
# 34453  https://www.facebook.com/apks4fun/posts/109933...          True
# 34454                       http://together.ucob.org.br/         False
# 34455          https://rainforestautomation.com/privacy/         False
# 34456       https://jekapps.com/politicas-de-privacidad/          True
# 34457    http://www.secumundi.com/uvv-apps/datasecurity/         False
# ...                                                  ...           ...
# 54341        https://gabarouch.wixsite.com/privacypolicy         False
# 54342        http://www.solcreo.co.jp/privacy/index.html          True
# 54343             http://ubitrix.com/privacy_policy.html          True
# 54344             http://smartwiremen.com/privacy-policy         False
# 54345            http://staffconnect-app.com/privacy.php         False
#
#        In_App_Purchases  Editors_Choice         Scraped_Time
# 34453             False           False  2021-06-15 20:53:49
# 34454             False           False  2021-06-15 20:53:50
# 34455             False           False  2021-06-15 20:53:50
# 34456             False           False  2021-06-15 20:53:50
# 34457             False           False  2021-06-15 20:53:50
# ...                 ...             ...                  ...
# 54341             False           False  2021-06-15 21:13:29
# 54342             False           False  2021-06-15 21:13:29
# 54343             False           False  2021-06-15 21:13:29
# 54344             False           False  2021-06-15 21:13:29
# 54345             False           False  2021-06-15 21:13:30
#
# [19893 rows x 24 columns]

# %% [markdown]
# # Finding and filling the null values in Free columns

# %%
df[df.Free.isnull()]
# Out:
# Empty DataFrame
# Columns: [App_Name, App_Id, Category, Rating, Rating_Count, Installs, Minimum_Installs, Maximum_Installs, Free, Price, Currency, Size, Minimum_Android, Developer_Id, Developer_Website, Developer_Email, Released, Last_Updated, Content_Rating, Privacy_Policy, Ad_Supported, In_App_Purchases, Editors_Choice, Scraped_Time]
# Index: []

# %%
df['Free'].fillna("Free",inplace=True)

# %%
df.isnull().sum()
# Out:
# App_Name                  2
# App_Id                    0
# Category                  0
# Rating                22883
# Rating_Count          22883
# Installs                107
# Minimum_Installs        107
# Maximum_Installs          0
# Free                      0
# Price                     0
# Currency                135
# Size                    196
# Minimum_Android        6530
# Developer_Id             33
# Developer_Website    760835
# Developer_Email          31
# Released              71053
# Last_Updated              0
# Content_Rating            0
# Privacy_Policy       420953
# Ad_Supported              0
# In_App_Purchases          0
# Editors_Choice            0
# Scraped_Time              0
# dtype: int64

# %% [markdown]
# # Content Rating (cleaning)

# %% [markdown]
# finding the null values in content Rating

# %%
df[df['Content_Rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App_Name, App_Id, Category, Rating, Rating_Count, Installs, Minimum_Installs, Maximum_Installs, Free, Price, Currency, Size, Minimum_Android, Developer_Id, Developer_Website, Developer_Email, Released, Last_Updated, Content_Rating, Privacy_Policy, Ad_Supported, In_App_Purchases, Editors_Choice, Scraped_Time]
# Index: []

# %% [markdown]
# looking for the missing value in the content rating

# %%
df.loc[34234:54653,:]
# Out:
#                                                 App_Name  \
# 34234  Cara Menjadi Kaya -How to become rich person M...
# 34235  HAJJA SARA AMMAL MATRIC HR SEC SCHOOL-Parent's...
# 34236                           Quizzes: Game Show Games
# 34237                                            Fiedora
# 34238                             New Zealand Newspapers
# ...                                                  ...
# 54649                               Dan Powers Advantage
# 54650                                    Inflight Reader
# 54651                                    ResolvedX Stage
# 54652                                在宅ケア支援システム（bmic-ZR）
# 54653                                      BEAT TRAINING
#
#                                            App_Id           Category  Rating  \
# 34234                      com.howto.getrichmalay  Books & Reference     0.0
# 34235                               com.hajjasara          Education     0.0
# 34236  top.freegames.generalknowledge.quiz.trivia             Trivia     NaN
# 34237                com.heimavista.pandoraSelfie        Photography     4.1
# 34238      com.newzealand.bydrcmob.newzealandnews   News & Magazines     0.0
# ...                                           ...                ...     ...
# 54649                 com.mobileappsprn.danpowers           Business     0.0
# 54650                com.magmakeredition.inflight   News & Magazines     3.0
# 54651                  com.sfl.is.resolvedx.stage           Business     0.0
# 54652                                  jp.bmic.zr            Medical     NaN
# 54653                    com.uphydn.beat_training              Tools     0.0
#
#        Rating_Count Installs  Minimum_Installs  Maximum_Installs  Free  Price  \
# 34234           0.0      10+              10.0                42  True    0.0
# 34235           0.0      10+              10.0                29  True    0.0
# 34236           NaN      50+              50.0                82  True    0.0
# 34237          64.0   5,000+            5000.0              7784  True    0.0
# 34238           0.0      50+              50.0                62  True    0.0
# ...             ...      ...               ...               ...   ...    ...
# 54649           0.0       5+               5.0                 7  True    0.0
# 54650          47.0   5,000+            5000.0              9161  True    0.0
# 54651           0.0       1+               1.0                 2  True    0.0
# 54652           NaN      10+              10.0                26  True    0.0
# 54653           0.0     100+             100.0               156  True    0.0
#
#       Currency                Size     Minimum_Android  \
# 34234      USD                4.9M          4.2 and up
# 34235      USD                5.7M          4.4 and up
# 34236      USD  Varies with device  Varies with device
# 34237      USD                 58M          5.0 and up
# 34238      USD                6.0M          4.1 and up
# ...        ...                 ...                 ...
# 54649      USD                 26M          5.0 and up
# 54650      USD                 20M        4.0.3 and up
# 54651      USD                 29M          7.0 and up
# 54652      USD  Varies with device  Varies with device
# 54653      USD                 68M          5.1 and up
#
#                           Developer_Id            Developer_Website  \
# 34234                           SRENNU                          NaN
# 34235                         HiFi Edu                          NaN
# 34236                       SAMP Games                          NaN
# 34237                 Heimavista, Inc.    http://www.heimavista.com
# 34238                          darcmob                          NaN
# ...                                ...                          ...
# 54649  Dealership for Life Mobile Apps       http://www.iteamhq.com
# 54650            magMaker Editions LLC  http://magmakereditions.com
# 54651   Next Generation Consulting LLC     http://www.resolvedx.io/
# 54652                      株式会社管理工学研究所         https://www.bmic.jp/
# 54653                           uphydn          https://uphydn.net/
#
#                    Developer_Email      Released  Last_Updated Content_Rating  \
# 34234         srenuga100@gmail.com   Jul 7, 2020  Jul 07, 2020       Everyone
# 34235           mhifiedu@gmail.com   Aug 9, 2020  Aug 09, 2020       Everyone
# 34236      rplinfotech00@gmail.com           NaN  Jan 29, 2021       Everyone
# 34237       service@heimavista.com  Jan 16, 2015  Jun 09, 2021       Everyone
# 34238            darcmob@gmail.com   Jun 6, 2020  Jun 06, 2020       Everyone
# ...                            ...           ...           ...            ...
# 54649         BrianKRoss@gmail.com  Jul 20, 2020  May 24, 2021       Everyone
# 54650  magMakerEditions@fsixty.com   Mar 3, 2014  Nov 02, 2016       Everyone
# 54651         support@resolvedx.io   Apr 9, 2021  Apr 20, 2021       Everyone
# 54652       bmic-info@kthree.co.jp           NaN  Jun 10, 2021       Everyone
# 54653             uphydn@gmail.com  Aug 23, 2019  Jul 16, 2020       Everyone
#
#                                           Privacy_Policy  Ad_Supported  \
# 34234  https://sites.google.com/view/srennu-privacy-p...          True
# 34235   http://mobileapi.hifiedu.net/privacy_policy.html         False
# 34236  https://rplprivacypolicy.blogspot.com/2019/06/...          True
# 34237         https://www.fiedora.com/zh-tw/privacy.html         False
# 34238  https://docs.google.com/document/d/e/2PACX-1vQ...          True
# ...                                                  ...           ...
# 54649        https://www.iteamhq.com/app-privacy-policy/         False
# 54650  http://www.inflightreader.com/pages/PrivacyPol...         False
# 54651        https://stage.resolvedx.io/#/privacy-policy         False
# 54652  https://www.kthree.co.jp/legal/legal_privacy.html         False
# 54653                    https://uphydn.net/privacy.html          True
#
#        In_App_Purchases  Editors_Choice         Scraped_Time
# 34234             False           False  2021-06-15 20:53:36
# 34235             False           False  2021-06-15 20:53:37
# 34236             False           False  2021-06-15 20:53:37
# 34237              True           False  2021-06-15 20:53:37
# 34238             False           False  2021-06-15 20:53:37
# ...                 ...             ...                  ...
# 54649             False           False  2021-06-15 21:13:47
# 54650              True           False  2021-06-15 21:13:47
# 54651             False           False  2021-06-15 21:13:47
# 54652             False           False  2021-06-15 21:13:47
# 54653              True           False  2021-06-15 21:13:47
#
# [20420 rows x 24 columns]

# %% [markdown]
# Droping the row from the column

# %%
df.dropna(subset =['Content_Rating'], inplace= True)

# %% [markdown]
# # Replaceing the missing values of the Rating Column with the Mode value of that entire column

# %%
modeRating=df['Rating'].mode()

# %%
df['Rating'].fillna(value=modeRating[0],inplace=True)

# %%
printinfo()
# Out:
#                   dataType  nullCount  uniqueCount
# App_Name            object          2      2177944
# App_Id              object          0      2312944
# Category            object          0           48
# Rating             float64          0           42
# Rating_Count       float64      22883        38482
# Installs            object        107           22
# Minimum_Installs   float64        107           22
# Maximum_Installs     int64          0       251563
# Free                  bool          0            2
# Price              float64          0         1063
# Currency            object        135           15
# Size                object        196         1657
# Minimum_Android     object       6530          154
# Developer_Id        object         33       758371
# Developer_Website   object     760835       810440
# Developer_Email     object         31       950456
# Released            object      71053         4158
# Last_Updated        object          0         3918
# Content_Rating      object          0            6
# Privacy_Policy      object     420953       977743
# Ad_Supported          bool          0            2
# In_App_Purchases      bool          0            2
# Editors_Choice        bool          0            2
# Scraped_Time        object          0        67374

# %% [markdown]
# # Column: Size

# %% [markdown]
# Converting the Size column to string

# %%
df['Size'] = df['Size'].astype(str)

# %% [markdown]
# Removing the + Symbol

# %%
df['Size'] = df.Size.apply(lambda x: x.strip('+'))

# %% [markdown]
# Removing the , Symbol

# %%
df['Size'] = df.Size.apply(lambda x:x.replace(',',''))

# %% [markdown]
#  For converting the M to 1000000

# %%
df['Size'] = df.Size.apply(lambda x: x.replace('M', 'e+6'))

# %% [markdown]
# Replacing the k by multiplying the value with 1000.

# %%
df['Size'] = df.Size.apply(lambda x: x.replace('k', 'e+3'))

# %%
df = df[df["Size"].str.contains("G") == False]

# %% [markdown]
# Replacing the Varies with device value with Nan.

# %%
df['Size'] = df.Size.replace('Varies with device',np.NaN)

# %% [markdown]
# droping the subset of size

# %%
df.dropna(subset = ['Size'], inplace=True)

# %% [markdown]
# Filling the null values

# %%
df['Size']= df['Size'].fillna(0)

# %% [markdown]
# Droping the null values

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1250858 entries, 0 to 2312942
# Data columns (total 24 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   App_Name           1250858 non-null  object
#  1   App_Id             1250858 non-null  object
#  2   Category           1250858 non-null  object
#  3   Rating             1250858 non-null  float64
#  4   Rating_Count       1250858 non-null  float64
#  5   Installs           1250858 non-null  object
#  6   Minimum_Installs   1250858 non-null  float64
#  7   Maximum_Installs   1250858 non-null  int64
#  8   Free               1250858 non-null  bool
#  9   Price              1250858 non-null  float64
#  10  Currency           1250858 non-null  object
#  11  Size               1250858 non-null  object
#  12  Minimum_Android    1250858 non-null  object
#  13  Developer_Id       1250858 non-null  object
#  14  Developer_Website  1250858 non-null  object
#  15  Developer_Email    1250858 non-null  object
#  16  Released           1250858 non-null  object
#  17  Last_Updated       1250858 non-null  object
#  18  Content_Rating     1250858 non-null  object
#  19  Privacy_Policy     1250858 non-null  object
#  20  Ad_Supported       1250858 non-null  bool
#  21  In_App_Purchases   1250858 non-null  bool
#  22  Editors_Choice     1250858 non-null  bool
#  23  Scraped_Time       1250858 non-null  object
# dtypes: bool(4), float64(4), int64(1), object(15)
# memory usage: 205.2+ MB

# %% [markdown]
# Finally converting to Numeric type.

# %%
df['Size'] = pd.to_numeric(df['Size'])

# %%
printinfo()
# Out:
#                   dataType  nullCount  uniqueCount
# App_Name            object          0      1210642
# App_Id              object          0      1250858
# Category            object          0           48
# Rating             float64          0           42
# Rating_Count       float64          0        31925
# Installs            object          0           20
# Minimum_Installs   float64          0           20
# Maximum_Installs     int64          0       188439
# Free                  bool          0            2
# Price              float64          0          607
# Currency            object          0            8
# Size               float64          0         1557
# Minimum_Android     object          0          106
# Developer_Id        object          0       441882
# Developer_Website   object          0       641735
# Developer_Email     object          0       546838
# Released            object          0         4154
# Last_Updated        object          0         3596
# Content_Rating      object          0            6
# Privacy_Policy      object          0       683800
# Ad_Supported          bool          0            2
# In_App_Purchases      bool          0            2
# Editors_Choice        bool          0            2
# Scraped_Time        object          0        67349

# %% [markdown]
# # Column: Installs

# %% [markdown]
# Converting the Installs column from object to str

# %%
df['Installs']=df.Installs.astype(str)

# %%
df.Installs
# Out:
# 0               10+
# 1            5,000+
# 4              100+
# 5               50+
# 9           50,000+
#              ...
# 2312933    500,000+
# 2312934          5+
# 2312938      1,000+
# 2312940        100+
# 2312942      1,000+
# Name: Installs, Length: 1250858, dtype: object

# %% [markdown]
#  Removing the + symbol from the values

# %%
df['Installs'] =df.Installs.apply(lambda x: x.strip('+'))

# %% [markdown]
# Removing the , from the numbers.

# %%
df['Installs'] =df.Installs.apply(lambda x: x.replace(',', ''))

# %% [markdown]
# Converting it from string type to numeric type

# %%
df['Installs'] = pd.to_numeric(df['Installs'])

# %%
df.Installs
# Out:
# 0              10
# 1            5000
# 4             100
# 5              50
# 9           50000
#             ...
# 2312933    500000
# 2312934         5
# 2312938      1000
# 2312940       100
# 2312942      1000
# Name: Installs, Length: 1250858, dtype: int64

# %% [markdown]
# Converting the Installs column from str to float

# %%
df['Installs']=df['Installs'].astype(float)

# %%
printinfo()
# Out:
#                   dataType  nullCount  uniqueCount
# App_Name            object          0      1210642
# App_Id              object          0      1250858
# Category            object          0           48
# Rating             float64          0           42
# Rating_Count       float64          0        31925
# Installs           float64          0           20
# Minimum_Installs   float64          0           20
# Maximum_Installs     int64          0       188439
# Free                  bool          0            2
# Price              float64          0          607
# Currency            object          0            8
# Size               float64          0         1557
# Minimum_Android     object          0          106
# Developer_Id        object          0       441882
# Developer_Website   object          0       641735
# Developer_Email     object          0       546838
# Released            object          0         4154
# Last_Updated        object          0         3596
# Content_Rating      object          0            6
# Privacy_Policy      object          0       683800
# Ad_Supported          bool          0            2
# In_App_Purchases      bool          0            2
# Editors_Choice        bool          0            2
# Scraped_Time        object          0        67349

# %% [markdown]
# # Column: Price

# %%
df['Price'].value_counts()
# Out:
# 0.000000     1228757
# 0.990000        4586
# 1.990000        2908
# 2.990000        2261
# 4.990000        1650
#               ...
# 2.148679           1
# 10.930000          1
# 48.800000          1
# 5.630000           1
# 3.041816           1
# Name: Price, Length: 607, dtype: int64

# %%
df["Price"].sum()
# Out:
# 133811.911669

# %% [markdown]
# # Exploratory Analysis and Visualization

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size']=18
matplotlib.rcParams['figure.figsize']=(15,10)
matplotlib.rcParams['figure.facecolor']='cyan'

# %% [markdown]
# exploreing the column of object type.

# %%
printinfo()
# Out:
#                   dataType  nullCount  uniqueCount
# App_Name            object          0      1210642
# App_Id              object          0      1250858
# Category            object          0           48
# Rating             float64          0           42
# Rating_Count       float64          0        31925
# Installs           float64          0           20
# Minimum_Installs   float64          0           20
# Maximum_Installs     int64          0       188439
# Free                  bool          0            2
# Price              float64          0          607
# Currency            object          0            8
# Size               float64          0         1557
# Minimum_Android     object          0          106
# Developer_Id        object          0       441882
# Developer_Website   object          0       641735
# Developer_Email     object          0       546838
# Released            object          0         4154
# Last_Updated        object          0         3596
# Content_Rating      object          0            6
# Privacy_Policy      object          0       683800
# Ad_Supported          bool          0            2
# In_App_Purchases      bool          0            2
# Editors_Choice        bool          0            2
# Scraped_Time        object          0        67349

# %% [markdown]
# Value count of the different section in category column

# %%
df['Category'].value_counts()
# Out:
# Education                  123772
# Business                    97744
# Music & Audio               85739
# Lifestyle                   73591
# Tools                       65156
# Entertainment               61992
# Books & Reference           55605
# Health & Fitness            50682
# Shopping                    48265
# Productivity                45417
# Travel & Local              45411
# Food & Drink                45045
# Finance                     42811
# Personalization             37212
# Communication               29907
# Sports                      28076
# News & Magazines            27961
# Social                      26543
# Puzzle                      23446
# Casual                      20717
# Medical                     19721
# Arcade                      19051
# Photography                 16493
# Maps & Navigation           15262
# Educational                 12373
# Simulation                  11919
# Action                      11637
# Auto & Vehicles             10436
# Adventure                    9796
# House & Home                 8499
# Events                       8309
# Art & Design                 7880
# Video Players & Editors      6558
# Beauty                       6116
# Trivia                       5715
# Role Playing                 5371
# Racing                       5056
# Board                        4888
# Word                         4757
# Card                         4355
# Strategy                     3890
# Weather                      3785
# Dating                       3273
# Casino                       2609
# Parenting                    2322
# Libraries & Demo             2297
# Music                        2127
# Comics                       1271
# Name: Category, dtype: int64

# %% [markdown]
# # Top category on playstore

# %%
y=df['Category'].value_counts().index
x=df['Category'].value_counts()
xaxis=[]
yaxis=[]
for i in range(len(x)) :
    xaxis.append(x[i])
    yaxis.append(y[i])

# %%
plt.figure(figsize=(25,18))
plt.xlabel('Count')
plt.ylabel('Category')
graph = sns.boxplot(x= xaxis, y = yaxis, palette = "husl")
graph.set_title("Top ones category on Play Store", fontsize = 30);

# %%
plt.figure(figsize=(25,18))
plt.xlabel('Count')
plt.ylabel('Category')
graph = sns.barplot(x= xaxis, y = yaxis, palette = "husl")
graph.set_title("Top ones category on Play Store", fontsize = 30);

# %%
plt.figure(figsize=(25,18))
plt.xlabel('Count')
plt.ylabel('Category')
graph = sns.scatterplot(x= xaxis, y = yaxis, palette = "husl")
graph.set_title("Top ones category on Play Store", fontsize = 30);
# Out:
# C:\Users\nager\AppData\Local\Temp\ipykernel_3040\2130369959.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   graph = sns.scatterplot(x= xaxis, y = yaxis, palette = "husl")

# %% [markdown]
# Note-: From the above graphs we come to know that there are total 50 categories in this dataset and the most apps on the playstore falls under the Education and Business  and the least falls under the
# comics

# %% [markdown]
# # Which category of Apps from the Content Rating column are found more on playstore

# %%
x2= df['Content_Rating'].value_counts().index
y2 =df['Content_Rating'].value_counts()

x2axis=[]
y2axis=[]
for i in range(len(x2)):
    x2axis.append(x2[i])
    y2axis.append(x2[i])

# %%
plt.figure(figsize=(20,18))
plt.bar(x2axis,y2axis,width=1,color=['grey','yellow','blue','green','purple','red'],alpha=1);
plt.title('Content_Rating',size = 28);
plt.ylabel('Apps(Count)');
plt.xlabel('Content Rating');

# %%
x2= df['Content_Rating'].value_counts().index
y2 =df['Content_Rating'].value_counts()

x2axis=[]
y2axis=[]
for i in range(len(x2)):
    x2axis.append(x2[i])
    y2axis.append(x2[i])

# %%
plt.figure(figsize=(20,18))
plt.scatter(x2axis,y2axis,color=['grey','yellow','blue','green','purple','red'],alpha=1);
plt.title('Content_Rating',size = 28);
plt.ylabel('Apps(Count)');
plt.xlabel('Content Rating');

# %% [markdown]
# Note: From the above plot we can see that Unrated category has the highest number of apps.

# %% [markdown]
# # Distribution of the ratings the dataframe.

# %%
df['Rating'].describe()
# Out:
# count    1.250858e+06
# mean     2.292466e+00
# std      2.094202e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      3.200000e+00
# 75%      4.300000e+00
# max      5.000000e+00
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(20,18))
graph = sns.kdeplot(df.Rating, color = 'red',shade = True)
plt.title('Distribution of Rating',size = 28);
plt.ylabel('Frequency');
plt.xlabel('Rating');

# %% [markdown]
# #  The apps in playstore are paid or free

# %%
plt.figure(figsize=(20,20))
labels=df['Free'].value_counts(sort =True).index
sizes =df['Free'].value_counts(sort=(True))
colors = ["red","green"]
explode =(0.3,0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors ,autopct='%2.2f',shadow = True, startangle=0)
plt.title('Percentage of Free Vs Paid Apps in Playstore',size=28)
plt.show()

# %% [markdown]
# Note: From the above graph we can see that 98.23%(Approx.) of apps in google play store are free and 1.77%(Approx.) are paid.

# %% [markdown]
# # Which category App's have most number of installs?

# %%
highest__Installs_df=df.groupby('Category')[['Installs']].sum().sort_values(by='Installs',ascending=False)

# %%
highest__Installs_df.head()
# Out:
#                 Installs
# Category
# Tools       2.053725e+10
# Action      1.302693e+10
# Casual      1.293569e+10
# Arcade      1.216118e+10
# Simulation  9.022042e+09

# %%
x2axis=[]
y2axis=[]
for i in range (len(highest__Installs_df)):
    x2axis.append(highest__Installs_df.Installs[i])
    y2axis.append(highest__Installs_df.index[i])
plt.figure(figsize=(25,18))
plt.xlabel("Installs")
plt.ylabel("Category")
graph=sns.barplot(x=x2axis,y=y2axis, alpha =1,palette = "viridis")
graph.set_title('Maximum Number Of Installs', fontsize = 25);

# %%
x2axis=[]
y2axis=[]
for i in range (len(highest__Installs_df)):
    x2axis.append(highest__Installs_df.Installs[i])
    y2axis.append(highest__Installs_df.index[i])
plt.figure(figsize=(25,18))
plt.xlabel("Installs")
plt.ylabel("Category")
graph=sns.boxplot(x=x2axis,y=y2axis,palette = "viridis")
graph.set_title('Maximum Number Of Installs', fontsize = 25);

# %% [markdown]
# Note: From the above visualization, it can be interpreted that the top categories with highest installs are Tools,Action,Arcade,Casual.

# %% [markdown]
# #  What are the Top 10 installed apps in any category?

# %%
def find_Top_10_In_Category(str):
     top10=df[df['Category']==str]
     top10apps=top10.sort_values(by='Installs',ascending=False).head(10)
     plt.figure(figsize=(25,20))
     plt.title('Top 10 Installed Apps',size=30);
     graph=sns.barplot(x=top10apps.App_Name, y =top10apps.Installs)
     graph.set_xticklabels(graph.get_xticklabels(), rotation= 45, horizontalalignment='right',)

# %%
find_Top_10_In_Category('Tools')
# Out:
# C:\Users\nager\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 10084 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nager\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 65039 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nager\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 10084 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nager\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 65039 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# C In the same way we by passing different category names to the function, we can get the top 10 installed apps.

# %%
find_Top_10_In_Category('Arcade')

# %% [markdown]
# Note: From the above graph we can see that in the Sports category Subway Surfers has the highest installs.

# %% [markdown]
# #  Which are the top 10 expensive Apps in playstore?

# %%
top10 = df[df['Free']==False]
print(top10)
top10_Paid_Apps = top10.sort_values(by=['Price'],ascending = False).head(5)
print(top10_Paid_Apps.head(5))
# Out:
#                                                   App_Name  \
# 296                          Standalone Golf GPS by Hole19
# 554                                        莎士比亞11連環錯（英漢對照）
# 618                                   Theme Park Simulator
# 637                                  Bukuu - Akibat Menipu
# 821                                            XBX and 5BX
# ...                                                    ...
# 2312483                                Swift Math Game PRO
# 2312628                                    Arduino 101 Kit
# 2312658                              VA-Beast Essentials-2
# 2312703                                 RPG Tears Revolude
# 2312803  New Cute Kitty Cats & Animals LOVE. WAStickerApps
#
#                                                     App_Id          Category  \
# 296                                    com.hole19golf.wear            Sports
# 554                     tw.com.mebook.generic4719180217042         Education
# 618       com.bestridesimulators.theme.park.simulator.game        Simulation
# 637                 bukuu.com.my.siri.haiwan.akibat.menipu         Education
# 821                                       app.li.xbxand5bx  Health & Fitness
# ...                                                    ...               ...
# 2312483                       com.pedrorocha.mathapp851319       Educational
# 2312628                                    com.tatco.curie         Education
# 2312658                     com.planeth.vabeastessentials2     Music & Audio
# 2312703                                 kemco.wws.revolude      Role Playing
# 2312803  com.wastickerapps.wasticker.sticker.emoji.new....     Entertainment
#
#          Rating  Rating_Count  Installs  Minimum_Installs  Maximum_Installs  \
# 296         2.8         160.0   10000.0           10000.0             10407
# 554         0.0           0.0       1.0               1.0                 2
# 618         3.8        1158.0   10000.0           10000.0             23644
# 637         0.0           0.0       1.0               1.0                 2
# 821         0.0           0.0     100.0             100.0               156
# ...         ...           ...       ...               ...               ...
# 2312483     4.2           5.0      10.0              10.0                18
# 2312628     0.0           0.0       5.0               5.0                 8
# 2312658     4.5          19.0    1000.0            1000.0              2686
# 2312703     4.5         568.0    5000.0            5000.0              6702
# 2312803     0.0           0.0       1.0               1.0                 3
#
#           Free  Price Currency        Size Minimum_Android  \
# 296      False   4.99      USD  30000000.0      7.1 and up
# 554      False   2.99      USD  17000000.0      4.4 and up
# 618      False   0.99      USD  36000000.0      4.4 and up
# 637      False   1.99      USD  30000000.0    2.3.3 and up
# 821      False   4.49      USD  34000000.0      5.0 and up
# ...        ...    ...      ...         ...             ...
# 2312483  False   1.99      USD   2500000.0      4.1 and up
# 2312628  False   5.49      USD  11000000.0      4.4 and up
# 2312658  False   1.99      USD    419000.0      5.0 and up
# 2312703  False   7.99      USD  47000000.0      2.3 and up
# 2312803  False   0.99      USD   5100000.0    4.0.3 and up
#
#                      Developer_Id  \
# 296                        Hole19
# 554                  Soyong Corp.
# 618          Best Ride Simulators
# 637         MMSC Ventures Sdn Bhd
# 821            Lovell Innovations
# ...                           ...
# 2312483                PedroRocha
# 2312628                 rabee2050
# 2312658              planet-h.com
# 2312703                     KEMCO
# 2312803  WAStickerApps WAStickers
#
#                                          Developer_Website  \
# 296                             https://www.hole19golf.com
# 554                               http://www.mebook.com.tw
# 618                          http://bestridesimulators.com
# 637                         http://www.mmsc.com.my/bukuu/
# 821      https://xbxand5bx.lovellinnovations.com/index....
# ...                                                    ...
# 2312483                        http://www.swiftmath.com.br
# 2312628                                    http://tatco.cc
# 2312658                           http://www.planet-h.com/
# 2312703                               http://www.kemco.jp/
# 2312803  https://sites.google.com/view/wastickerapps-wa...
#
#                          Developer_Email      Released  Last_Updated  \
# 296                  help@hole19golf.com   Feb 7, 2017  Dec 22, 2020
# 554           welcome@mail.soyong.com.tw  Mar 15, 2017  Mar 15, 2017
# 618                cuentas.brs@gmail.com   Nov 3, 2020  Feb 05, 2021
# 637                 bukuu.mmsc@gmail.com  Jan 12, 2016  Jan 13, 2016
# 821        contact@lovellinnovations.com   Jan 2, 2021  May 14, 2021
# ...                                  ...           ...           ...
# 2312483           pedrovqrocha@gmail.com  Dec 13, 2016  Jan 26, 2019
# 2312628                    info@tatco.cc   Nov 1, 2017  Apr 06, 2019
# 2312658            gstomper@planet-h.com   Jul 7, 2014  Oct 03, 2020
# 2312703                 android@kemco.jp  Jul 16, 2015  Jul 16, 2015
# 2312803  wastickerappsstickers@gmail.com   Feb 6, 2019  Feb 06, 2019
#
#         Content_Rating                                     Privacy_Policy  \
# 296           Everyone    https://www.hole19golf.com/terms/#PrivacyPolicy
# 554           Everyone  http://mobile.mebook-buy.com/android/privacy.html
# 618           Everyone  https://bestridesimulators.com/lunaria-games-s-l/
# 637           Everyone  https://www.mmsc.com.my/bukuu/terma-penggunaan...
# 821           Everyone  http://xbxand5bx.lovellinnovations.com/legal/p...
# ...                ...                                                ...
# 2312483       Everyone             http://swiftmath.com.br/privacy-policy
# 2312628       Everyone  https://sites.google.com/site/rabee2050/home/p...
# 2312658       Everyone                  https://www.planet-h.com/privacy/
# 2312703           Teen            http://www.kemco.jp/app_pp/privacy.html
# 2312803       Everyone  https://sites.google.com/view/wastickerapps-wa...
#
#          Ad_Supported  In_App_Purchases  Editors_Choice         Scraped_Time
# 296             False             False           False  2021-06-15 20:19:53
# 554             False             False           False  2021-06-15 20:20:07
# 618              True              True           False  2021-06-15 20:20:11
# 637             False             False           False  2021-06-15 20:20:13
# 821             False             False           False  2021-06-15 20:20:23
# ...               ...               ...             ...                  ...
# 2312483         False             False           False  2021-06-16 12:58:54
# 2312628         False             False           False  2021-06-16 12:59:02
# 2312658         False             False           False  2021-06-16 12:59:03
# 2312703          True              True           False  2021-06-16 12:59:06
# 2312803         False             False           False  2021-06-16 12:59:11
#
# [22101 rows x 24 columns]
#                                  App_Name  \
# 544468                       MESH Connect
# 1399820          Most expensive word game
# 1859780                              AudD
# 1327436  Youmeunit PRO — ver.4U4M34353RY1
# 2085590      Series Addict Pro - TV Guide
#
#                                               App_Id       Category  Rating  \
# 544468   com.tecit.android.bluepiano.meshconnectfull   Productivity     0.0
# 1399820          com.wMostexpensivewordgame_10919836          Board     3.4
# 1859780                              io.audd.android  Music & Audio     3.2
# 1327436                            com.youmeunit.pro         Social     0.0
# 2085590               com.alamkanak.seriesaddict.pro  Entertainment     4.1
#
#          Rating_Count  Installs  Minimum_Installs  Maximum_Installs   Free  \
# 544468            0.0      10.0              10.0                25  False
# 1399820         122.0    5000.0            5000.0              5523  False
# 1859780          66.0    1000.0            1000.0              4397  False
# 1327436           0.0       0.0               0.0                 0  False
# 2085590          58.0     500.0             500.0               639  False
#
#           Price Currency        Size Minimum_Android     Developer_Id  \
# 544468   400.00      USD  20000000.0      4.4 and up           Go Evo
# 1399820  399.99      USD  24000000.0      4.4 and up           Vadaaa
# 1859780  399.99      USD   2100000.0      5.0 and up        AudD, LLC
# 1327436  399.99      USD  11000000.0     4.4W and up  Misshapen Cloud
# 2085590  399.99      USD   5400000.0      5.0 and up   Raquib-ul Alam
#
#                                          Developer_Website  \
# 544468                               http://www.go-evo.com
# 1399820                                  http://Vadaaa.com
# 1859780                                    https://audd.io
# 1327436                              https://youmeunit.com
# 2085590  https://alamkanak.github.io/Series-Addict-App-...
#
#               Developer_Email      Released  Last_Updated Content_Rating  \
# 544468     support@go-evo.com   Sep 7, 2017  Sep 07, 2017       Everyone
# 1399820      f251s5@yahoo.com  May 11, 2020  Oct 13, 2020       Everyone
# 1859780         hello@audd.io  Feb 17, 2018  Feb 17, 2018       Everyone
# 1327436   youmeunit@gmail.com  Oct 14, 2020  Feb 12, 2021       Everyone
# 2085590  alam.kanak@gmail.com   Oct 8, 2014  Jun 03, 2021           Teen
#
#                                             Privacy_Policy  Ad_Supported  \
# 544468                       http://www.go-evo.com/privacy         False
# 1399820                                  http://Vadaaa.com          True
# 1859780                           https://audd.io/privacy/         False
# 1327436  https://docs.google.com/document/d/16rNB5A40UC...         False
# 2085590  https://alamkanak.github.io/Series-Addict-App-...         False
#
#          In_App_Purchases  Editors_Choice         Scraped_Time
# 544468              False           False  2021-06-16 05:15:22
# 1399820             False           False  2021-06-15 23:46:04
# 1859780             False           False  2021-06-16 06:24:31
# 1327436              True           False  2021-06-15 22:34:28
# 2085590             False           False  2021-06-16 09:40:51

# %%
top10_Paid_Apps_df = top10_Paid_Apps[['App_Name', 'Installs']]

# %%
plt.figure(figsize=(20,15));
plt.pie(top10_Paid_Apps_df.Installs, explode=None, labels=top10_Paid_Apps_df.App_Name, autopct='%4.3f%%', startangle=30);
plt.title('Top Expensive Apps Distribution',size = 20);
plt.legend(top10_Paid_Apps_df.App_Name, 
           loc="lower left",
           title="App_Name",
           fontsize = "x-small"
          );

# %% [markdown]
# Note: From the above graph we can interprete that the App Most Expensive word game is the most expensive app in the google playstore followed by AudD.

# %% [markdown]
# #  Which are the Apps with highest number of rating?

# %%
AppwithHighestrev=df.sort_values(by='Rating',ascending=False).head(10)
AppwithHighestrev
# Out:
#                               App_Name                              App_Id  \
# 534320                    Delico Store              com.qiotic.delicostore
# 1711859  Electronics Reuse Conference‬                 events.socio.app307
# 302552                        Mudakhir                        com.mudakhir
# 2105991                       GlassGet                    com.bsg.glassget
# 981367                       عالم رقمى                com.sis.digitalworld
# 1571166                 SPERA HOT YOGA  com.fitnessmobileapps.sperahotyoga
# 302583                           Dümen                       com.dumen.app
# 1975054   Wiener tarife 2018 Crna Gora      me.wiener.android.tarife.x2018
# 1092875                      Digimealz                store.digimealz.menu
# 470026           Dicas para o Carnaval           com.wgpapps.dicascarnaval
#
#                  Category  Rating  Rating_Count  Installs  Minimum_Installs  \
# 534320           Shopping     5.0           7.0    5000.0            5000.0
# 1711859          Business     5.0           6.0     100.0             100.0
# 302552            Finance     5.0           5.0      10.0              10.0
# 2105991      House & Home     5.0           6.0     500.0             500.0
# 981367   News & Magazines     5.0           9.0     100.0             100.0
# 1571166  Health & Fitness     5.0           5.0    1000.0            1000.0
# 302583             Events     5.0          14.0      10.0              10.0
# 1975054           Finance     5.0           9.0     100.0             100.0
# 1092875      Food & Drink     5.0          10.0      10.0              10.0
# 470026             Events     5.0          22.0      50.0              50.0
#
#          Maximum_Installs  Free  Price Currency         Size Minimum_Android  \
# 534320               6452  True    0.0      USD   82000000.0      5.0 and up
# 1711859               343  True    0.0      USD  102000000.0      6.0 and up
# 302552                 30  True    0.0      USD   12000000.0      4.1 and up
# 2105991               742  True    0.0      USD   56000000.0      7.0 and up
# 981367                243  True    0.0      USD   25000000.0      4.2 and up
# 1571166              1166  True    0.0      USD    6000000.0      4.1 and up
# 302583                 41  True    0.0      USD   24000000.0    4.0.3 and up
# 1975054               272  True    0.0      USD   68000000.0      4.4 and up
# 1092875                11  True    0.0      USD   30000000.0      4.1 and up
# 470026                 61  True    0.0      USD    2600000.0      4.1 and up
#
#                        Developer_Id                  Developer_Website  \
# 534320                 Delico Store              https://delico.store/
# 1711859              Socio Labs Inc               https://socio.events
# 302552                     Mudakhir           https://www.Mudakhir.com
# 2105991                   BSG GLASS           http://www.bsgglass.com/
# 981367   Smart Integrated Solutions         http://www.alamrakamy.com/
# 1571166       MINDBODY Branded Apps      http://www.mindbodyonline.com
# 302583                Seyyid Öztürk        http://www.seyyidozturk.com
# 1975054                        WSŽO            http://www.wiener.co.me
# 1092875                  Neobertech             https://digimealz.com/
# 470026                     WGP Apps  https://sa0e3b545.app-ads-txt.com
#
#                     Developer_Email      Released  Last_Updated  \
# 534320              info@delico.app  Oct 20, 2019  Apr 22, 2020
# 1711859        support@socio.events  Oct 11, 2018  May 07, 2021
# 302552        Mudakhirapp@gmail.com   Aug 1, 2020  Dec 06, 2020
# 2105991           info@bsgglass.com  May 15, 2020  May 20, 2021
# 981367          info@alamrakamy.com  Jul 18, 2019  Dec 06, 2020
# 1571166  support@mindbodyonline.com  Jan 25, 2016  Jan 14, 2019
# 302583     seyyidozturk07@gmail.com   Feb 4, 2018  Feb 04, 2018
# 1975054    wienercrnagora@gmail.com  Dec 29, 2017  Jun 09, 2021
# 1092875       support@digimealz.com  Mar 30, 2021  Mar 31, 2021
# 470026         wgp_apps@hotmail.com  Feb 15, 2020  Feb 15, 2020
#
#         Content_Rating                                     Privacy_Policy  \
# 534320        Everyone                https://delico.store/privacy-policy
# 1711859       Everyone                 https://socio.events/privacypolicy
# 302552        Everyone             https://mudakhir.com/PrivacyPolicy.pdf
# 2105991       Everyone  https://bsgendlessexperience.com/news/content/...
# 981367        Everyone                             https://alamrakamy.com
# 1571166       Everyone       http://www.mindbodyonline.com/privacy-policy
# 302583        Everyone  http://seyyidozturk.com/document/dumen/privacy...
# 1975054       Everyone                            http://www.wiener.co.me
# 1092875       Everyone                https://digimealz.com/store/privacy
# 470026    Everyone 10+  http://w8privacy.azurewebsites.net/privacy?dev...
#
#          Ad_Supported  In_App_Purchases  Editors_Choice         Scraped_Time
# 534320          False             False           False  2021-06-16 05:06:16
# 1711859         False             False           False  2021-06-16 04:20:50
# 302552          False              True           False  2021-06-16 01:31:25
# 2105991         False             False           False  2021-06-16 09:58:42
# 981367           True             False           False  2021-06-16 12:01:02
# 1571166         False             False           False  2021-06-16 02:23:55
# 302583           True             False           False  2021-06-16 01:31:27
# 1975054         False             False           False  2021-06-16 08:04:23
# 1092875         False             False           False  2021-06-16 13:48:33
# 470026           True             False           False  2021-06-16 04:08:17

# %% [markdown]
# #  What are the count of Apps in different genres?

# %%
top_apps_in_genres=df['Category'].value_counts().head(10)

# %%
x3axis = []
y3axis = []
for i in range(len(top_apps_in_genres)):
    x3axis.append(top_apps_in_genres.index[i])
    y3axis.append(top_apps_in_genres[i])

# %%
plt.figure(figsize=(15,9))
plt.ylabel('Genres(App Count)')
plt.xlabel('Genres')
graph = sns.barplot(x=x3axis,y=y3axis,palette="deep")
graph.set_xticklabels(graph.get_xticklabels(), rotation=45, fontsize=18)
graph.set_title("Top Genres in the Playstore", fontsize = 20);

# %% [markdown]
# Note: From the above visualization we can see that the Highest Number of Apps found in the Tools and Business genres followed by Education, Medical and many more.

# %% [markdown]
# #  Which are the apps that have made the highest earning?

# %%
paid_apps_df=df[df['Free']==False]

# %%
earnings_df=paid_apps_df[['App_Name','Installs','Price']]

# %%
earnings_df['Earnings']=paid_apps_df['Installs']*paid_apps_df['Price']
# Out:
# C:\Users\nager\AppData\Local\Temp/ipykernel_9968/4203358835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   earnings_df['Earnings']=paid_apps_df['Installs']*paid_apps_df['Price']

# %%
earnings_df_sorted_by_Earnings = earnings_df.sort_values(by='Earnings',ascending=False).head(50)

# %%
earning_df_sorted_by_Price = earnings_df_sorted_by_Earnings.sort_values(by='Price', ascending=False)

# %%
plt.figure(figsize=(50,40))
plt.xlabel("App_name",size=40)
plt.ylabel("Earnings",size=40)
plt.bar(earning_df_sorted_by_Price.App_Name, earning_df_sorted_by_Price.Earnings, width=1.1, label=earning_df_sorted_by_Price.Earnings)
plt.tick_params(rotation=90)
plt.title("Top Earning Apps",size=40);

# %% [markdown]
# # Inferences and Conclusion
#
# After Analyzing the dataset I have got answers to some of the serious & interesting question which any of the android users would love to know.
#
# Top categories on Google Playstore?
# Which category of Content are found more?
# Distribution of the ratings of the apps?
# What percentage of apps are Free and Paid?
# Which category of App's have most number of installs?
# What are the Top 10 installed apps in different category?
# Which are the top expensive Apps?
# Which are the Apps with highest number of reviews?
# Count of Apps found in different genres?
# Which are the apps that have made the highest earning?
# After the completion of my project and the course I have learned and got exposure to different tools and techniques in data analysis. I was able to complete the project successfully with the help of tools like Python, Pandas, Matplotlib, Numpy, Seaborn. Also I learned different techniques like Data Cleaning, Data Preparation, Data Exploration and visualization, and Data Interpretation.
